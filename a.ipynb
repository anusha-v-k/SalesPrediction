# %%
import requests

url = "http://localhost:5000/convert"   # your API endpoint
params = {"c": 30}                       # Celsius value

response = requests.get(url, params=params)

response.json()  # shows the Fahrenheit value
# Out:
# {'fahrenheit': 86.0}

# %%
import requests

url = "https://api.coingecko.com/api/v3/simple/price"
params = {
    "ids": "bitcoin",
    "vs_currencies": "usd"
}

response = requests.get(url, params=params)
data = response.json()

print("Bitcoin Price (USD):", data["bitcoin"]["usd"])
# Out:
# Bitcoin Price (USD): 93007

# %%
import requests

url = "https://api.coingecko.com/api/v3/simple/price"
params = {
    "ids": "bitcoin,ethereum,solana",
    "vs_currencies": "usd,inr"
}

response = requests.get(url, params=params).json()
print(response)
# Out:
# {'bitcoin': {'usd': 92953, 'inr': 8346609}, 'ethereum': {'usd': 3208.61, 'inr': 288113}, 'solana': {'usd': 143.21, 'inr': 12859.25}}

# %%
import requests

url = "https://www.reddit.com/r/news/.json"
headers = {"User-Agent": "Mozilla/5.0"}

response = requests.get(url, headers=headers).json()

for post in response["data"]["children"][:5]:
    print(post["data"]["title"])
# Out:
# FBI arrests suspect in Jan. 6 pipe bomb case: MS NOW
# California launches portal for public to report alleged ICE wrongdoing
# Putin ‘morally responsible’ for Dawn Sturgess’s novichok death, inquiry finds
# Pentagon watchdog finds Hegseth’s use of Signal posed risk to US personnel, AP sources say
# A vocal Jeffrey Epstein accuser is urging judges to unseal his court records
